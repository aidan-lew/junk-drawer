# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme(style="whitegrid")

# Load the example dataset of brain network correlations
df = sns.load_dataset("brain_networks", header=[0, 1, 2], index_col=0)

# Pull out a specific subset of networks
used_networks = [1, 3, 4, 5, 6, 7, 8, 11, 12, 13, 16, 17]
used_columns = (df.columns.get_level_values("network")
                          .astype(int)
                          .isin(used_networks))
df = df.loc[:, used_columns]

# Compute the correlation matrix and average over networks
corr_df = df.corr().groupby(level="network").mean()
corr_df.index = corr_df.index.astype(int)
corr_df = corr_df.sort_index().T

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 6))

# Draw a violinplot with a narrower bandwidth than the default
sns.violinplot(data=corr_df, palette="Set3", bw=.2, cut=1, linewidth=1)

# Finalize the figure
ax.set(ylim=(-.7, 1.05))
sns.despine(left=True, bottom=True)

# %%
import seaborn as sns
penguins = sns.load_dataset("penguins")
#penguins.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-2-84524caae669> in <module>
#       1 import seaborn as sns
# ----> 2 penguins = sns.load_dataset("penguins")
#       3 #penguins.head()
#
# /Applications/miniconda3/lib/python3.8/site-packages/seaborn/utils.py in load_dataset(name, cache, data_home, **kws)
#     515
#     516     if name == "penguins":
# --> 517         df["sex"] = df["sex"].str.title()
#     518
#     519     if name == "diamonds":
#
# /Applications/miniconda3/lib/python3.8/site-packages/pandas/core/strings/accessor.py in wrapper(self, *args, **kwargs)
#      99                 )
#     100                 raise TypeError(msg)
# --> 101             return func(self, *args, **kwargs)
#     102
#     103         wrapper.__name__ = func_name
#
# /Applications/miniconda3/lib/python3.8/site-packages/pandas/core/strings/accessor.py in title(self)
#    2689     @forbid_nonstring_types(["bytes"])
#    2690     def title(self):
# -> 2691         result = self._data.array._str_title()
#    2692         return self._wrap_result(result)
#    2693
#
# AttributeError: 'PandasArray' object has no attribute '_str_title'

# %%
import catboost

# %%
# Load the example dataset of brain network correlations
df = sns.load_dataset("brain_networks", header=[0, 1, 2], index_col=0)

df.head()
# Out:
# network          1                     2                     3             \
# node             1                     1                     1
# hemi            lh         rh         lh         rh         lh         rh
# 0        56.055744  92.031036   3.391576  38.659683  26.203819 -49.715569
# 1        55.547253  43.690075 -65.495987 -13.974523 -28.274963 -39.050129
# 2        60.997768  63.438793 -51.108582 -13.561346 -18.842947  -1.214659
# 3        18.514868  12.657158 -34.576603 -32.665958  -7.420454  17.119448
# 4        -2.527392 -63.104668 -13.814151 -15.837989 -45.216927   3.483550
#
# network          4                     5             ...         16  \
# node             1                     1             ...          3
# hemi            lh         rh         lh         rh  ...         rh
# 0        47.461037  26.746613 -35.898861  -1.889181  ...   0.607904
# 1        -1.210660 -19.012897  19.568010  15.902983  ...  57.495071
# 2       -65.575806 -85.777428  19.247454  37.209419  ...  28.317369
# 3       -41.800869 -58.610184  32.896915  11.199619  ...  71.439629
# 4       -62.613335 -49.076508  18.396759   3.219077  ...  95.597565
#
# network                                17                                   \
# node             4                      1                     2
# hemi            lh          rh         lh         rh         lh         rh
# 0       -70.270546   77.365776 -21.734550   1.028253   7.791784  68.903725
# 1       -76.393219  127.261360 -13.035799  46.381824 -15.752450  31.000332
# 2         9.063977   45.493263  26.033442  34.212200   1.326110 -22.580757
# 3        65.842979  -10.697547  55.297466   4.255006  -2.420144  12.098393
# 4        50.960453  -23.197300  43.067562  52.219875  28.232882 -11.719750
#
# network
# node             3                      4
# hemi            lh          rh         lh
# 0       -10.520872  120.490463 -39.686432
# 1       -39.607521   24.764011 -36.771008
# 2        12.985169  -75.027451   6.434262
# 3       -15.819172  -37.361431  -4.650954
# 4         5.453649    5.169828  87.809135
#
# [5 rows x 62 columns]

# %%
# Pull out a specific subset of networks
used_networks = [1, 3, 4, 5, 6, 7, 8, 11, 12, 13, 16, 17]
used_columns = (df.columns.get_level_values("network")
                          .astype(int)
                          .isin(used_networks))
df = df.loc[:, used_columns]

df.head()
# Out:
# network          1                     3                     4             \
# node             1                     1                     1
# hemi            lh         rh         lh         rh         lh         rh
# 0        56.055744  92.031036  26.203819 -49.715569  47.461037  26.746613
# 1        55.547253  43.690075 -28.274963 -39.050129  -1.210660 -19.012897
# 2        60.997768  63.438793 -18.842947  -1.214659 -65.575806 -85.777428
# 3        18.514868  12.657158  -7.420454  17.119448 -41.800869 -58.610184
# 4        -2.527392 -63.104668 -45.216927   3.483550 -62.613335 -49.076508
#
# network          5                     6             ...         16  \
# node             1                     1             ...          3
# hemi            lh         rh         lh         rh  ...         rh
# 0       -35.898861  -1.889181   5.898688 -43.692322  ...   0.607904
# 1        19.568010  15.902983 -23.231823 -10.745867  ...  57.495071
# 2        19.247454  37.209419   2.392153  16.509109  ...  28.317369
# 3        32.896915  11.199619 -14.665752   2.073715  ...  71.439629
# 4        18.396759   3.219077 -41.856911 -24.690414  ...  95.597565
#
# network                                17                                   \
# node             4                      1                     2
# hemi            lh          rh         lh         rh         lh         rh
# 0       -70.270546   77.365776 -21.734550   1.028253   7.791784  68.903725
# 1       -76.393219  127.261360 -13.035799  46.381824 -15.752450  31.000332
# 2         9.063977   45.493263  26.033442  34.212200   1.326110 -22.580757
# 3        65.842979  -10.697547  55.297466   4.255006  -2.420144  12.098393
# 4        50.960453  -23.197300  43.067562  52.219875  28.232882 -11.719750
#
# network
# node             3                      4
# hemi            lh          rh         lh
# 0       -10.520872  120.490463 -39.686432
# 1       -39.607521   24.764011 -36.771008
# 2        12.985169  -75.027451   6.434262
# 3       -15.819172  -37.361431  -4.650954
# 4         5.453649    5.169828  87.809135
#
# [5 rows x 52 columns]

# %%
# Compute the correlation matrix and average over networks
corr_df = df.corr().groupby(level="network").mean()
corr_df.index = corr_df.index.astype(int)
corr_df = corr_df.sort_index().T
corr_df.head()
# Out:
# network                  1         3         4         5         6         7   \
# network node hemi
# 1       1    lh    0.940758 -0.256174 -0.367388  0.425164 -0.057770 -0.275816
#              rh    0.940758 -0.256757 -0.335360  0.475935 -0.012364 -0.229890
# 3       1    lh   -0.347179  0.776591  0.516095 -0.171081  0.195136  0.215233
#              rh   -0.165752  0.776591  0.328505 -0.098206  0.192752  0.133581
# 4       1    lh   -0.353147  0.415503  0.907364 -0.234307  0.131866  0.366093
#
# network                  8         11        12        13        16        17
# network node hemi
# 1       1    lh   -0.360677 -0.350165 -0.037846 -0.277132 -0.210971 -0.178113
#              rh   -0.343731 -0.366285 -0.079787 -0.330986 -0.249845 -0.241018
# 3       1    lh    0.023386 -0.180107 -0.105693 -0.138277 -0.084444 -0.036002
#              rh   -0.075293 -0.236928 -0.116453 -0.181868 -0.099662 -0.094679
# 4       1    lh    0.155278 -0.143028 -0.145737 -0.091319 -0.074776 -0.034908

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme(style="white", rc={"axes.facecolor": (0, 0, 0, 0)})
# Create the data
rs = np.random.RandomState(1979)
x = rs.randn(500)
g = np.tile(list("ABCDEFGHIJ"), 50)
df = pd.DataFrame(dict(x=x, g=g))
m = df.g.map(ord)
df["x"] += m

# Initialize the FacetGrid object
pal = sns.cubehelix_palette(10, rot=-.25, light=.7)
g = sns.FacetGrid(df, row="g", hue="g", aspect=15, height=.5, palette=pal)

# Draw the densities in a few steps
g.map(sns.kdeplot, "x",
      bw_adjust=.5, clip_on=False,
      fill=True, alpha=1, linewidth=1.5)
g.map(sns.kdeplot, "x", clip_on=False, color="w", lw=2, bw_adjust=.5)
g.map(plt.axhline, y=0, lw=2, clip_on=False)


# Define and use a simple function to label the plot in axes coordinates
def label(x, color, label):
    ax = plt.gca()
    ax.text(0, .2, label, fontweight="bold", color=color,
            ha="left", va="center", transform=ax.transAxes)


g.map(label, "x")

# Set the subplots to overlap
g.fig.subplots_adjust(hspace=-.25)

# Remove axes details that don't play well with overlap
g.set_titles("")
g.set(yticks=[])
g.despine(bottom=True, left=True)
# Out:
# /Applications/miniconda3/lib/python3.8/site-packages/seaborn/axisgrid.py:64: UserWarning: Tight layout not applied. tight_layout cannot make axes height small enough to accommodate all axes decorations
#   self.fig.tight_layout(*args, **kwargs)
# /Applications/miniconda3/lib/python3.8/site-packages/seaborn/axisgrid.py:64: UserWarning: Tight layout not applied. tight_layout cannot make axes height small enough to accommodate all axes decorations
#   self.fig.tight_layout(*args, **kwargs)

# %%
df.head(15)
# Out:
#             x  g
# 0   64.038123  A
# 1   66.147050  B
# 2   66.370011  C
# 3   68.791019  D
# 4   70.583534  E
# 5   69.135114  F
# 6   72.390092  G
# 7   73.822191  H
# 8   73.868785  I
# 9   72.938377  J
# 10  65.723433  A
# 11  66.580572  B
# 12  68.631715  C
# 13  68.175267  D
# 14  68.772384  E

# %%
penguins = sns.load_dataset("penguins")

penguins.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
pip install utils
# Out:
# Collecting utils
#   Downloading utils-1.0.1-py2.py3-none-any.whl (21 kB)
# Installing collected packages: utils
# Successfully installed utils-1.0.1
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install mxnet
# Out:
#   File "<ipython-input-3-eb1936f8d912>", line 1
#     pip install mxnet
#         ^
# SyntaxError: invalid syntax

# %%
conda config --add channels conda-forge
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
conda install catboost
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.10.1
#   latest version: 4.10.3
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /Applications/miniconda3
#
#   added / updated specs:
#     - catboost
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     blas-1.0                   |              mkl           6 KB
#     ca-certificates-2021.5.30  |       h033912b_0         136 KB  conda-forge
#     catboost-0.26.1            |   py38h50d1736_0        10.7 MB  conda-forge
#     certifi-2021.5.30          |   py38h50d1736_0         141 KB  conda-forge
#     conda-4.10.3               |   py38h50d1736_1         3.1 MB  conda-forge
#     intel-openmp-2021.3.0      |    hecd8cb5_3375         950 KB
#     libgfortran-3.0.1          |                0         495 KB  conda-forge
#     mkl-2021.3.0               |     hecd8cb5_517       100.4 MB
#     mkl-service-2.4.0          |   py38h96a0964_0          43 KB  conda-forge
#     mkl_fft-1.3.0              |   py38h4a7008c_2         163 KB
#     mkl_random-1.2.2           |   py38hb2f4e1b_0         273 KB
#     numpy-1.20.3               |   py38h4b4dc7a_0          23 KB
#     numpy-base-1.20.3          |   py38he0bd621_0         4.4 MB
#     openssl-1.1.1l             |       h0d85af4_0         1.9 MB  conda-forge
#     pandas-1.0.5               |   py38h5fc983b_0         9.8 MB  conda-forge
#     python-dateutil-2.8.2      |     pyhd8ed1ab_0         240 KB  conda-forge
#     python_abi-3.8             |           2_cp38           4 KB  conda-forge
#     pytz-2021.1                |     pyhd8ed1ab_0         239 KB  conda-forge
#     scipy-1.7.1                |   py38h88652d9_2        15.5 MB
#     ------------------------------------------------------------
#                                            Total:       148.3 MB
#
# The following NEW packages will be INSTALLED:
#
#   blas               pkgs/main/osx-64::blas-1.0-mkl
#   catboost           conda-forge/osx-64::catboost-0.26.1-py38h50d1736_0
#   intel-openmp       pkgs/main/osx-64::intel-openmp-2021.3.0-hecd8cb5_3375
#   libgfortran        conda-forge/osx-64::libgfortran-3.0.1-0
#   mkl                pkgs/main/osx-64::mkl-2021.3.0-hecd8cb5_517
#   mkl-service        conda-forge/osx-64::mkl-service-2.4.0-py38h96a0964_0
#   mkl_fft            pkgs/main/osx-64::mkl_fft-1.3.0-py38h4a7008c_2
#   mkl_random         pkgs/main/osx-64::mkl_random-1.2.2-py38hb2f4e1b_0
#   numpy              pkgs/main/osx-64::numpy-1.20.3-py38h4b4dc7a_0
#   numpy-base         pkgs/main/osx-64::numpy-base-1.20.3-py38he0bd621_0
#   pandas             conda-forge/osx-64::pandas-1.0.5-py38h5fc983b_0
#   python-dateutil    conda-forge/noarch::python-dateutil-2.8.2-pyhd8ed1ab_0
#   python_abi         conda-forge/osx-64::python_abi-3.8-2_cp38
#   pytz               conda-forge/noarch::pytz-2021.1-pyhd8ed1ab_0
#   scipy              pkgs/main/osx-64::scipy-1.7.1-py38h88652d9_2
#
# The following packages will be UPDATED:
#
#   ca-certificates    pkgs/main::ca-certificates-2021.4.13-~ --> conda-forge::ca-certificates-2021.5.30-h033912b_0
#   certifi            pkgs/main::certifi-2020.12.5-py38hecd~ --> conda-forge::certifi-2021.5.30-py38h50d1736_0
#   conda              pkgs/main::conda-4.10.1-py38hecd8cb5_1 --> conda-forge::conda-4.10.3-py38h50d1736_1
#   openssl              pkgs/main::openssl-1.1.1k-h9ed2024_0 --> conda-forge::openssl-1.1.1l-h0d85af4_0
#
#
#
# Downloading and Extracting Packages
# libgfortran-3.0.1    | 495 KB    | ##################################### | 100%
# numpy-1.20.3         | 23 KB     | ##################################### | 100%
# pandas-1.0.5         | 9.8 MB    | ##################################### | 100%
# numpy-base-1.20.3    | 4.4 MB    | ##################################### | 100%
# python-dateutil-2.8. | 240 KB    | ##################################### | 100%
# mkl-service-2.4.0    | 43 KB     | ##################################### | 100%
# scipy-1.7.1          | 15.5 MB   | ##################################### | 100%
# mkl_fft-1.3.0        | 163 KB    | ##################################### | 100%
# ca-certificates-2021 | 136 KB    | ##################################### | 100%
# mkl-2021.3.0         | 100.4 MB  | ##################################### | 100%
# mkl_random-1.2.2     | 273 KB    | ##################################### | 100%
# conda-4.10.3         | 3.1 MB    | ##################################### | 100%
# python_abi-3.8       | 4 KB      | ##################################### | 100%
# catboost-0.26.1      | 10.7 MB   | ##################################### | 100%
# pytz-2021.1          | 239 KB    | ##################################### | 100%
# certifi-2021.5.30    | 141 KB    | ##################################### | 100%
# blas-1.0             | 6 KB      | ##################################### | 100%
# intel-openmp-2021.3. | 950 KB    | ##################################### | 100%
# openssl-1.1.1l       | 1.9 MB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install ipywidgets
# Out:
# Collecting ipywidgets
#   Downloading ipywidgets-7.6.5-py2.py3-none-any.whl (121 kB)
#      |████████████████████████████████| 121 kB 2.7 MB/s eta 0:00:01
# Requirement already satisfied: ipython>=4.0.0; python_version >= "3.3" in /Applications/miniconda3/lib/python3.8/site-packages (from ipywidgets) (7.23.1)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /Applications/miniconda3/lib/python3.8/site-packages (from ipywidgets) (0.2.0)
# Collecting widgetsnbextension~=3.5.0
#   Downloading widgetsnbextension-3.5.1-py2.py3-none-any.whl (2.2 MB)
#      |████████████████████████████████| 2.2 MB 10.5 MB/s eta 0:00:01
# Collecting jupyterlab-widgets>=1.0.0; python_version >= "3.6"
#   Downloading jupyterlab_widgets-1.0.2-py3-none-any.whl (243 kB)
#      |████████████████████████████████| 243 kB 14.3 MB/s eta 0:00:01
# Requirement already satisfied: ipykernel>=4.5.1 in /Applications/miniconda3/lib/python3.8/site-packages (from ipywidgets) (5.5.4)
# Requirement already satisfied: traitlets>=4.3.1 in /Applications/miniconda3/lib/python3.8/site-packages (from ipywidgets) (5.0.5)
# Requirement already satisfied: nbformat>=4.2.0 in /Applications/miniconda3/lib/python3.8/site-packages (from ipywidgets) (5.1.3)
# Requirement already satisfied: appnope; sys_platform == "darwin" in /Applications/miniconda3/lib/python3.8/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets) (0.1.2)
# Requirement already satisfied: setuptools>=18.5 in /Applications/miniconda3/lib/python3.8/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets) (50.3.1.post20201107)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /Applications/miniconda3/lib/python3.8/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets) (3.0.18)
# Requirement already satisfied: pexpect>4.3; sys_platform != "win32" in /Applications/miniconda3/lib/python3.8/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets) (4.8.0)
# Requirement already satisfied: jedi>=0.16 in /Applications/miniconda3/lib/python3.8/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets) (0.18.0)
# Requirement already satisfied: pygments in /Applications/miniconda3/lib/python3.8/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets) (2.9.0)
# Requirement already satisfied: matplotlib-inline in /Applications/miniconda3/lib/python3.8/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets) (0.1.2)
# Requirement already satisfied: decorator in /Applications/miniconda3/lib/python3.8/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets) (5.0.7)
# Requirement already satisfied: pickleshare in /Applications/miniconda3/lib/python3.8/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets) (0.7.5)
# Requirement already satisfied: backcall in /Applications/miniconda3/lib/python3.8/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets) (0.2.0)
# Requirement already satisfied: notebook>=4.4.1 in /Applications/miniconda3/lib/python3.8/site-packages (from widgetsnbextension~=3.5.0->ipywidgets) (6.3.0)
# Requirement already satisfied: jupyter-client in /Applications/miniconda3/lib/python3.8/site-packages (from ipykernel>=4.5.1->ipywidgets) (6.1.12)
# Requirement already satisfied: tornado>=4.2 in /Applications/miniconda3/lib/python3.8/site-packages (from ipykernel>=4.5.1->ipywidgets) (6.1)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /Applications/miniconda3/lib/python3.8/site-packages (from nbformat>=4.2.0->ipywidgets) (3.2.0)
# Requirement already satisfied: jupyter-core in /Applications/miniconda3/lib/python3.8/site-packages (from nbformat>=4.2.0->ipywidgets) (4.7.1)
# Requirement already satisfied: wcwidth in /Applications/miniconda3/lib/python3.8/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0; python_version >= "3.3"->ipywidgets) (0.2.5)
# Requirement already satisfied: ptyprocess>=0.5 in /Applications/miniconda3/lib/python3.8/site-packages (from pexpect>4.3; sys_platform != "win32"->ipython>=4.0.0; python_version >= "3.3"->ipywidgets) (0.7.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Applications/miniconda3/lib/python3.8/site-packages (from jedi>=0.16->ipython>=4.0.0; python_version >= "3.3"->ipywidgets) (0.8.2)
# Requirement already satisfied: pyzmq>=17 in /Applications/miniconda3/lib/python3.8/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (22.0.3)
# Requirement already satisfied: nbconvert in /Applications/miniconda3/lib/python3.8/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (6.0.7)
# Requirement already satisfied: Send2Trash>=1.5.0 in /Applications/miniconda3/lib/python3.8/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (1.5.0)
# Requirement already satisfied: prometheus-client in /Applications/miniconda3/lib/python3.8/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.10.1)
# Requirement already satisfied: terminado>=0.8.3 in /Applications/miniconda3/lib/python3.8/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.9.4)
# Requirement already satisfied: argon2-cffi in /Applications/miniconda3/lib/python3.8/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (20.1.0)
# Requirement already satisfied: jinja2 in /Applications/miniconda3/lib/python3.8/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (2.11.3)
# Requirement already satisfied: python-dateutil>=2.1 in /Applications/miniconda3/lib/python3.8/site-packages (from jupyter-client->ipykernel>=4.5.1->ipywidgets) (2.8.2)
# Requirement already satisfied: pyrsistent>=0.14.0 in /Applications/miniconda3/lib/python3.8/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets) (0.17.3)
# Requirement already satisfied: attrs>=17.4.0 in /Applications/miniconda3/lib/python3.8/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets) (21.1.0)
# Requirement already satisfied: six>=1.11.0 in /Applications/miniconda3/lib/python3.8/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets) (1.15.0)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in /Applications/miniconda3/lib/python3.8/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.5.3)
# Requirement already satisfied: entrypoints>=0.2.2 in /Applications/miniconda3/lib/python3.8/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.3)
# Requirement already satisfied: bleach in /Applications/miniconda3/lib/python3.8/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (3.3.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /Applications/miniconda3/lib/python3.8/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (1.4.3)
# Requirement already satisfied: testpath in /Applications/miniconda3/lib/python3.8/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.4.4)
# Requirement already satisfied: defusedxml in /Applications/miniconda3/lib/python3.8/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.7.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in /Applications/miniconda3/lib/python3.8/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.8.4)
# Requirement already satisfied: jupyterlab-pygments in /Applications/miniconda3/lib/python3.8/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.1.2)
# Requirement already satisfied: cffi>=1.0.0 in /Applications/miniconda3/lib/python3.8/site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (1.14.3)
# Requirement already satisfied: MarkupSafe>=0.23 in /Applications/miniconda3/lib/python3.8/site-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (1.1.1)
# Requirement already satisfied: nest-asyncio in /Applications/miniconda3/lib/python3.8/site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (1.5.1)
# Requirement already satisfied: async-generator in /Applications/miniconda3/lib/python3.8/site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (1.10)
# Requirement already satisfied: packaging in /Applications/miniconda3/lib/python3.8/site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (20.9)
# Requirement already satisfied: webencodings in /Applications/miniconda3/lib/python3.8/site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.5.1)
# Requirement already satisfied: pycparser in /Applications/miniconda3/lib/python3.8/site-packages (from cffi>=1.0.0->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (2.20)
# Requirement already satisfied: pyparsing>=2.0.2 in /Applications/miniconda3/lib/python3.8/site-packages (from packaging->bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (2.4.7)
# Installing collected packages: widgetsnbextension, jupyterlab-widgets, ipywidgets
# Successfully installed ipywidgets-7.6.5 jupyterlab-widgets-1.0.2 widgetsnbextension-3.5.1
# Note: you may need to restart the kernel to use updated packages.

# %%
# !jupyter nbextension enable --py widgetsnbextension
# Out:
# Enabling notebook extension jupyter-js-widgets/extension...
#       - Validating: OK

# %%
# Install Homebrew
/usr/bin/ruby -e "$(curl -fsSL https://raw.githubusercontent.com/Homebrew/install/master/install)"
export PATH=/usr/local/bin:/usr/local/sbin:$PATH

# Install python development tools - python2.7, pip, python-setuptools
brew install python
# Out:
#   File "<ipython-input-10-ef507c0b1b5d>", line 3
#     export PATH=/usr/local/bin:/usr/local/sbin:$PATH
#            ^
# SyntaxError: invalid syntax

# %%
pip install mxnet
# Out:
# Collecting mxnet
#   Downloading mxnet-1.6.0-cp38-cp38-macosx_10_12_x86_64.whl (16.6 MB)
#      |████████████████████████████████| 16.6 MB 16.3 MB/s eta 0:00:01
# Collecting graphviz<0.9.0,>=0.8.1
#   Downloading graphviz-0.8.4-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: numpy<2.0.0,>1.16.0 in /Applications/miniconda3/lib/python3.8/site-packages (from mxnet) (1.20.3)
# Requirement already satisfied: requests<3,>=2.20.0 in /Applications/miniconda3/lib/python3.8/site-packages (from mxnet) (2.24.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Applications/miniconda3/lib/python3.8/site-packages (from requests<3,>=2.20.0->mxnet) (2021.5.30)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /Applications/miniconda3/lib/python3.8/site-packages (from requests<3,>=2.20.0->mxnet) (1.25.11)
# Requirement already satisfied: chardet<4,>=3.0.2 in /Applications/miniconda3/lib/python3.8/site-packages (from requests<3,>=2.20.0->mxnet) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /Applications/miniconda3/lib/python3.8/site-packages (from requests<3,>=2.20.0->mxnet) (2.10)
# Installing collected packages: graphviz, mxnet
# ERROR: After October 2020 you may experience errors when installing or updating packages. This is because pip will change the way that it resolves dependency conflicts.
#
# We recommend you use --use-feature=2020-resolver to test your packages with the new resolver before it becomes the default.
#
# catboost 0.26.1 requires plotly, which is not installed.
# Successfully installed graphviz-0.8.4 mxnet-1.6.0
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install graphviz
# Out:
# Requirement already satisfied: graphviz in /Applications/miniconda3/lib/python3.8/site-packages (0.8.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install plotly
# Out:
# Collecting plotly
#   Downloading plotly-5.3.1-py2.py3-none-any.whl (23.9 MB)
#      |████████████████████████████████| 23.9 MB 13.5 MB/s eta 0:00:01
# Collecting tenacity>=6.2.0
#   Downloading tenacity-8.0.1-py3-none-any.whl (24 kB)
# Requirement already satisfied: six in /Applications/miniconda3/lib/python3.8/site-packages (from plotly) (1.15.0)
# Installing collected packages: tenacity, plotly
# Successfully installed plotly-5.3.1 tenacity-8.0.1
# Note: you may need to restart the kernel to use updated packages.

# %%
conda install -c conda-forge xgboost
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /Applications/miniconda3
#
#   added / updated specs:
#     - xgboost
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _py-xgboost-mutex-2.0      |            cpu_0           8 KB  conda-forge
#     joblib-1.0.1               |     pyhd8ed1ab_0         206 KB  conda-forge
#     libxgboost-1.3.3           |       h23ab428_0         1.2 MB
#     llvm-openmp-12.0.1         |       hda6cdc1_1         287 KB  conda-forge
#     py-xgboost-1.3.3           |   py38hecd8cb5_0         136 KB
#     scikit-learn-0.24.2        |   py38hb2f4e1b_0         4.9 MB
#     threadpoolctl-2.2.0        |     pyh8a188c0_0          16 KB  conda-forge
#     xgboost-1.3.3              |   py38hecd8cb5_0          23 KB
#     ------------------------------------------------------------
#                                            Total:         6.7 MB
#
# The following NEW packages will be INSTALLED:
#
#   _py-xgboost-mutex  conda-forge/osx-64::_py-xgboost-mutex-2.0-cpu_0
#   joblib             conda-forge/noarch::joblib-1.0.1-pyhd8ed1ab_0
#   libxgboost         pkgs/main/osx-64::libxgboost-1.3.3-h23ab428_0
#   llvm-openmp        conda-forge/osx-64::llvm-openmp-12.0.1-hda6cdc1_1
#   py-xgboost         pkgs/main/osx-64::py-xgboost-1.3.3-py38hecd8cb5_0
#   scikit-learn       pkgs/main/osx-64::scikit-learn-0.24.2-py38hb2f4e1b_0
#   threadpoolctl      conda-forge/noarch::threadpoolctl-2.2.0-pyh8a188c0_0
#   xgboost            pkgs/main/osx-64::xgboost-1.3.3-py38hecd8cb5_0
#
#
#
# Downloading and Extracting Packages
# _py-xgboost-mutex-2. | 8 KB      | ##################################### | 100%
# llvm-openmp-12.0.1   | 287 KB    | ##################################### | 100%
# libxgboost-1.3.3     | 1.2 MB    | ##################################### | 100%
# joblib-1.0.1         | 206 KB    | ##################################### | 100%
# threadpoolctl-2.2.0  | 16 KB     | ##################################### | 100%
# scikit-learn-0.24.2  | 4.9 MB    | ##################################### | 100%
# py-xgboost-1.3.3     | 136 KB    | ##################################### | 100%
# xgboost-1.3.3        | 23 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: /
#
#     Installed package of scikit-learn can be accelerated using scikit-learn-intelex.
#     More details are available here: https://intel.github.io/scikit-learn-intelex
#
#     For example:
#
#         $ conda install scikit-learn-intelex
#         $ python -m sklearnex my_application.py
#
#
#
# done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install openpyxl
# Out:
# Requirement already satisfied: openpyxl in /Applications/miniconda3/lib/python3.8/site-packages (3.0.7)
# Requirement already satisfied: et-xmlfile in /Applications/miniconda3/lib/python3.8/site-packages (from openpyxl) (1.1.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
git clone https://github.com/catboost/tutorials
# Out:
#   File "<ipython-input-1-6ebaaa564f32>", line 1
#     git clone https://github.com/catboost/tutorials
#         ^
# SyntaxError: invalid syntax

# %%
conda update pandas
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /Applications/miniconda3
#
#   added / updated specs:
#     - pandas
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     brotlipy-0.7.0             |py38hed1de0f_1004         367 KB  conda-forge
#     bzip2-1.0.8                |       h0d85af4_4         155 KB  conda-forge
#     ca-certificates-2022.6.15  |       h033912b_0         149 KB  conda-forge
#     certifi-2022.6.15          |   py38h50d1736_0         155 KB  conda-forge
#     cffi-1.15.1                |   py38h86886aa_0         221 KB  conda-forge
#     charset-normalizer-2.1.0   |     pyhd8ed1ab_0          35 KB  conda-forge
#     colorama-0.4.5             |     pyhd8ed1ab_0          18 KB  conda-forge
#     conda-4.13.0               |   py38h50d1736_1         989 KB  conda-forge
#     conda-package-handling-1.8.1|   py38hed1de0f_1         1.7 MB  conda-forge
#     cryptography-37.0.1        |   py38hf6deb26_0         1.1 MB
#     idna-3.3                   |     pyhd8ed1ab_0          55 KB  conda-forge
#     joblib-1.1.0               |     pyhd8ed1ab_0         210 KB  conda-forge
#     libblas-3.9.0              |15_osx64_openblas          12 KB  conda-forge
#     libcblas-3.9.0             |15_osx64_openblas          12 KB  conda-forge
#     libcxx-14.0.6              |       hce7ea42_0         1.3 MB  conda-forge
#     libffi-3.4.2               |       h0d85af4_5          50 KB  conda-forge
#     libgfortran-5.0.0          |9_3_0_h6c81a4c_23          19 KB  conda-forge
#     libgfortran5-9.3.0         |      h6c81a4c_23         1.7 MB  conda-forge
#     liblapack-3.9.0            |15_osx64_openblas          12 KB  conda-forge
#     libopenblas-0.3.20         |openmp_hb3cd9ec_0         9.6 MB  conda-forge
#     libzlib-1.2.12             |       hfe4f2af_1          63 KB  conda-forge
#     llvm-openmp-14.0.4         |       ha654fa7_0         329 KB  conda-forge
#     ncurses-6.3                |       h96cf925_1         915 KB  conda-forge
#     numpy-1.23.0               |   py38h604f2a5_0         6.7 MB  conda-forge
#     openssl-3.0.4              |       hfe4f2af_2         2.5 MB  conda-forge
#     pandas-1.4.3               |   py38h2b30649_0        11.8 MB  conda-forge
#     pip-22.1.2                 |     pyhd8ed1ab_0         1.5 MB  conda-forge
#     pycosat-0.6.3              |py38hed1de0f_1010         114 KB  conda-forge
#     pycparser-2.21             |     pyhd8ed1ab_0         100 KB  conda-forge
#     pyopenssl-22.0.0           |     pyhd8ed1ab_0          49 KB  conda-forge
#     pysocks-1.7.1              |   py38h50d1736_5          28 KB  conda-forge
#     python-3.8.13              |h66c20e1_0_cpython        12.8 MB  conda-forge
#     pytz-2022.1                |     pyhd8ed1ab_0         242 KB  conda-forge
#     readline-8.1.2             |       h3899abd_0         266 KB  conda-forge
#     requests-2.28.1            |     pyhd8ed1ab_0          53 KB  conda-forge
#     ruamel_yaml-0.15.80        |py38h0dd4459_1007         243 KB  conda-forge
#     scikit-learn-1.1.1         |   py38h4ade575_0         7.6 MB  conda-forge
#     scipy-1.8.1                |   py38h2c99f22_0        22.0 MB  conda-forge
#     setuptools-63.1.0          |   py38h50d1736_0         1.4 MB  conda-forge
#     six-1.16.0                 |     pyh6c4a22f_0          14 KB  conda-forge
#     sqlite-3.39.0              |       hd9f0692_0         1.8 MB  conda-forge
#     threadpoolctl-3.1.0        |     pyh8a188c0_0          18 KB  conda-forge
#     tk-8.6.12                  |       h5dbffcc_0         3.4 MB  conda-forge
#     tqdm-4.64.0                |     pyhd8ed1ab_0          81 KB  conda-forge
#     urllib3-1.26.9             |     pyhd8ed1ab_0         100 KB  conda-forge
#     wheel-0.37.1               |     pyhd8ed1ab_0          31 KB  conda-forge
#     xz-5.2.5                   |       haf1e3a3_1         228 KB  conda-forge
#     yaml-0.2.5                 |       h0d85af4_2          82 KB  conda-forge
#     zlib-1.2.12                |       hfe4f2af_1          93 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        92.2 MB
#
# The following NEW packages will be INSTALLED:
#
#   bzip2              conda-forge/osx-64::bzip2-1.0.8-h0d85af4_4
#   charset-normalizer conda-forge/noarch::charset-normalizer-2.1.0-pyhd8ed1ab_0
#   colorama           conda-forge/noarch::colorama-0.4.5-pyhd8ed1ab_0
#   libblas            conda-forge/osx-64::libblas-3.9.0-15_osx64_openblas
#   libcblas           conda-forge/osx-64::libcblas-3.9.0-15_osx64_openblas
#   libgfortran5       conda-forge/osx-64::libgfortran5-9.3.0-h6c81a4c_23
#   liblapack          conda-forge/osx-64::liblapack-3.9.0-15_osx64_openblas
#   libopenblas        conda-forge/osx-64::libopenblas-0.3.20-openmp_hb3cd9ec_0
#   libzlib            conda-forge/osx-64::libzlib-1.2.12-hfe4f2af_1
#
# The following packages will be REMOVED:
#
#   blas-1.0-mkl
#   chardet-3.0.4-py38hecd8cb5_1003
#   intel-openmp-2021.3.0-hecd8cb5_3375
#   libedit-3.1.20191231-h1de35cc_1
#   mkl-2021.3.0-hecd8cb5_517
#   mkl-service-2.4.0-py38h96a0964_0
#   mkl_fft-1.3.0-py38h4a7008c_2
#   mkl_random-1.2.2-py38hb2f4e1b_0
#   numpy-base-1.20.3-py38he0bd621_0
#
# The following packages will be UPDATED:
#
#   brotlipy           pkgs/main::brotlipy-0.7.0-py38h9ed202~ --> conda-forge::brotlipy-0.7.0-py38hed1de0f_1004
#   ca-certificates                      2021.5.30-h033912b_0 --> 2022.6.15-h033912b_0
#   certifi                          2021.5.30-py38h50d1736_0 --> 2022.6.15-py38h50d1736_0
#   cffi                pkgs/main::cffi-1.14.3-py38h2125817_2 --> conda-forge::cffi-1.15.1-py38h86886aa_0
#   conda                               4.10.3-py38h50d1736_1 --> 4.13.0-py38h50d1736_1
#   conda-package-han~ pkgs/main::conda-package-handling-1.7~ --> conda-forge::conda-package-handling-1.8.1-py38hed1de0f_1
#   cryptography                         3.2.1-py38hbcfaee0_1 --> 37.0.1-py38hf6deb26_0
#   idna                            pkgs/main::idna-2.10-py_0 --> conda-forge::idna-3.3-pyhd8ed1ab_0
#   joblib                                 1.0.1-pyhd8ed1ab_0 --> 1.1.0-pyhd8ed1ab_0
#   libcxx                         pkgs/main::libcxx-10.0.0-1 --> conda-forge::libcxx-14.0.6-hce7ea42_0
#   libffi                   pkgs/main::libffi-3.3-hb1e8313_2 --> conda-forge::libffi-3.4.2-h0d85af4_5
#   libgfortran                                       3.0.1-0 --> 5.0.0-9_3_0_h6c81a4c_23
#   llvm-openmp                             12.0.1-hda6cdc1_1 --> 14.0.4-ha654fa7_0
#   ncurses                 pkgs/main::ncurses-6.2-h0a44026_1 --> conda-forge::ncurses-6.3-h96cf925_1
#   numpy              pkgs/main::numpy-1.20.3-py38h4b4dc7a_0 --> conda-forge::numpy-1.23.0-py38h604f2a5_0
#   openssl                                 1.1.1l-h0d85af4_0 --> 3.0.4-hfe4f2af_2
#   pandas                               1.0.5-py38h5fc983b_0 --> 1.4.3-py38h2b30649_0
#   pip                pkgs/main/osx-64::pip-20.2.4-py38hecd~ --> conda-forge/noarch::pip-22.1.2-pyhd8ed1ab_0
#   pycosat            pkgs/main::pycosat-0.6.3-py38h1de35cc~ --> conda-forge::pycosat-0.6.3-py38hed1de0f_1010
#   pycparser                  pkgs/main::pycparser-2.20-py_2 --> conda-forge::pycparser-2.21-pyhd8ed1ab_0
#   pyopenssl          pkgs/main::pyopenssl-19.1.0-pyhd3eb1b~ --> conda-forge::pyopenssl-22.0.0-pyhd8ed1ab_0
#   pysocks                   pkgs/main::pysocks-1.7.1-py38_1 --> conda-forge::pysocks-1.7.1-py38h50d1736_5
#   python                 pkgs/main::python-3.8.5-h26836e1_1 --> conda-forge::python-3.8.13-h66c20e1_0_cpython
#   pytz                                  2021.1-pyhd8ed1ab_0 --> 2022.1-pyhd8ed1ab_0
#   readline               pkgs/main::readline-8.0-h1de35cc_0 --> conda-forge::readline-8.1.2-h3899abd_0
#   requests                  pkgs/main::requests-2.24.0-py_0 --> conda-forge::requests-2.28.1-pyhd8ed1ab_0
#   scikit-learn       pkgs/main::scikit-learn-0.24.2-py38hb~ --> conda-forge::scikit-learn-1.1.1-py38h4ade575_0
#   scipy               pkgs/main::scipy-1.7.1-py38h88652d9_2 --> conda-forge::scipy-1.8.1-py38h2c99f22_0
#   setuptools         pkgs/main::setuptools-50.3.1-py38hecd~ --> conda-forge::setuptools-63.1.0-py38h50d1736_0
#   six                pkgs/main/osx-64::six-1.15.0-py38hecd~ --> conda-forge/noarch::six-1.16.0-pyh6c4a22f_0
#   sqlite                pkgs/main::sqlite-3.33.0-hffcf06c_0 --> conda-forge::sqlite-3.39.0-hd9f0692_0
#   threadpoolctl                          2.2.0-pyh8a188c0_0 --> 3.1.0-pyh8a188c0_0
#   tk                        pkgs/main::tk-8.6.10-hb0a8c7a_0 --> conda-forge::tk-8.6.12-h5dbffcc_0
#   tqdm                  pkgs/main::tqdm-4.51.0-pyhd3eb1b0_0 --> conda-forge::tqdm-4.64.0-pyhd8ed1ab_0
#   urllib3                   pkgs/main::urllib3-1.25.11-py_0 --> conda-forge::urllib3-1.26.9-pyhd8ed1ab_0
#   wheel                pkgs/main::wheel-0.35.1-pyhd3eb1b0_0 --> conda-forge::wheel-0.37.1-pyhd8ed1ab_0
#   xz                         pkgs/main::xz-5.2.5-h1de35cc_0 --> conda-forge::xz-5.2.5-haf1e3a3_1
#   yaml                     pkgs/main::yaml-0.2.5-haf1e3a3_0 --> conda-forge::yaml-0.2.5-h0d85af4_2
#   zlib                    pkgs/main::zlib-1.2.11-h1de35cc_3 --> conda-forge::zlib-1.2.12-hfe4f2af_1
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   ruamel_yaml        pkgs/main::ruamel_yaml-0.15.87-py38ha~ --> conda-forge::ruamel_yaml-0.15.80-py38h0dd4459_1007
#
#
#
# Downloading and Extracting Packages
# libgfortran5-9.3.0   | 1.7 MB    | ##################################### | 100%
# bzip2-1.0.8          | 155 KB    | ##################################### | 100%
# charset-normalizer-2 | 35 KB     | ##################################### | 100%
# urllib3-1.26.9       | 100 KB    | ##################################### | 100%
# scikit-learn-1.1.1   | 7.6 MB    | ##################################### | 100%
# tqdm-4.64.0          | 81 KB     | ##################################### | 100%
# certifi-2022.6.15    | 155 KB    | ##################################### | 100%
# requests-2.28.1      | 53 KB     | ##################################### | 100%
# cryptography-37.0.1  | 1.1 MB    | ##################################### | 100%
# readline-8.1.2       | 266 KB    | ##################################### | 100%
# libffi-3.4.2         | 50 KB     | ##################################### | 100%
# pysocks-1.7.1        | 28 KB     | ##################################### | 100%
# libcblas-3.9.0       | 12 KB     | ##################################### | 100%
# setuptools-63.1.0    | 1.4 MB    | ##################################### | 100%
# brotlipy-0.7.0       | 367 KB    | ##################################### | 100%
# ca-certificates-2022 | 149 KB    | ##################################### | 100%
# colorama-0.4.5       | 18 KB     | ##################################### | 100%
# zlib-1.2.12          | 93 KB     | ##################################### | 100%
# pyopenssl-22.0.0     | 49 KB     | ##################################### | 100%
# idna-3.3             | 55 KB     | ##################################### | 100%
# ncurses-6.3          | 915 KB    | ##################################### | 100%
# liblapack-3.9.0      | 12 KB     | ##################################### | 100%
# xz-5.2.5             | 228 KB    | ##################################### | 100%
# wheel-0.37.1         | 31 KB     | ##################################### | 100%
# tk-8.6.12            | 3.4 MB    | ##################################### | 100%
# numpy-1.23.0         | 6.7 MB    | ##################################### | 100%
# pandas-1.4.3         | 11.8 MB   | ##################################### | 100%
# libopenblas-0.3.20   | 9.6 MB    | ##################################### | 100%
# threadpoolctl-3.1.0  | 18 KB     | ##################################### | 100%
# yaml-0.2.5           | 82 KB     | ##################################### | 100%
# libblas-3.9.0        | 12 KB     | ##################################### | 100%
# pycosat-0.6.3        | 114 KB    | ##################################### | 100%
# libzlib-1.2.12       | 63 KB     | ##################################### | 100%
# cffi-1.15.1          | 221 KB    | ##################################### | 100%
# pip-22.1.2           | 1.5 MB    | ##################################### | 100%
# scipy-1.8.1          | 22.0 MB   | ##################################### | 100%
# sqlite-3.39.0        | 1.8 MB    | ##################################### | 100%
# libgfortran-5.0.0    | 19 KB     | ##################################### | 100%
# pycparser-2.21       | 100 KB    | ##################################### | 100%
# python-3.8.13        | 12.8 MB   | ##################################### | 100%
# ruamel_yaml-0.15.80  | 243 KB    | ##################################### | 100%
# conda-4.13.0         | 989 KB    | ##################################### | 100%
# joblib-1.1.0         | 210 KB    | ##################################### | 100%
# libcxx-14.0.6        | 1.3 MB    | ##################################### | 100%
# conda-package-handli | 1.7 MB    | ##################################### | 100%
# six-1.16.0           | 14 KB     | ##################################### | 100%
# openssl-3.0.4        | 2.5 MB    | ##################################### | 100%
# llvm-openmp-14.0.4   | 329 KB    | ##################################### | 100%
# pytz-2022.1          | 242 KB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
conda install bert
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# Collecting package metadata (repodata.json): done
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
#
# PackagesNotFoundError: The following packages are not available from current channels:
#
#   - bert
#
# Current channels:
#
#   - https://conda.anaconda.org/conda-forge/osx-64
#   - https://conda.anaconda.org/conda-forge/noarch
#   - https://repo.anaconda.com/pkgs/main/osx-64
#   - https://repo.anaconda.com/pkgs/main/noarch
#   - https://repo.anaconda.com/pkgs/r/osx-64
#   - https://repo.anaconda.com/pkgs/r/noarch
#
# To search for alternate channels that may provide the conda package you're
# looking for, navigate to
#
#     https://anaconda.org
#
# and use the search bar at the top of the page.
#
#
#
# Note: you may need to restart the kernel to use updated packages.
