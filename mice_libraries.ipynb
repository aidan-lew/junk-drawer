# %%
#Thank you to Ning Leow for compiling the following libraries (https://medium.com/@ningleow/python-packages-for-the-rodent-neuroscientist-3f2b2074bd77)
#Anatomy & Microscopy
import brainreg
import brainrender
import cellfinder
import bg-atlasapi 
import cellpose
import MorphometricAnalysis
import BarDensr

#Ca2+ imaging
suite2p
CaImAn
SIMA 
Cascade
fissa
LocaNMF
# Out:
#   File "<ipython-input-9-e61cf6879cb1>", line 6
#     import bg-atlasapi
#              ^
# SyntaxError: invalid syntax

# %%
pip install suite2p
# Out:
# ...
#      |████████████████████████████████| 638 kB 2.8 MB/s eta 0:00:01
# ...
#   Using cached torch-1.9.1-cp38-none-macosx_10_9_x86_64.whl (218.8 MB)
# ...
#      |████████████████████████████████| 989 kB 8.6 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 80 kB 6.9 MB/s  eta 0:00:01
# ...
#      |████████████████████████████████| 206 kB 16.9 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 959 kB 15.3 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 380 kB 16.2 MB/s eta 0:00:01
# ...
#   ERROR: Command errored out with exit status 1:
# ...

# %%
pip install CaImAn
# Out:
# ERROR: Could not find a version that satisfies the requirement CaImAn (from versions: none)
# ERROR: No matching distribution found for CaImAn
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install SIMA
# Out:
# ...
#      |████████████████████████████████| 3.1 MB 2.6 MB/s eta 0:00:01     |█████████████████▉              | 1.7 MB 2.6 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 1.0 MB 8.6 MB/s eta 0:00:01
# ...
#   ERROR: Command errored out with exit status 1:
#    command: /Applications/miniconda3/bin/python -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/xz/lqj_5zgn7x3_j2w_c_dy8vr00000gn/T/pip-install-jhf6_yp0/sima/setup.py'"'"'; __file__='"'"'/private/var/folders/xz/lqj_5zgn7x3_j2w_c_dy8vr00000gn/T/pip-install-jhf6_yp0/sima/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d /private/var/folders/xz/lqj_5zgn7x3_j2w_c_dy8vr00000gn/T/pip-wheel-fsvp2s8y
#        cwd: /private/var/folders/xz/lqj_5zgn7x3_j2w_c_dy8vr00000gn/T/pip-install-jhf6_yp0/sima/
#   Complete output (162 lines):
#   running bdist_wheel
# ...

# %%
pip install Cascade
fissa
LocaNMF
# Out:
#   File "<ipython-input-11-4e3a3e483420>", line 1
#     pip install Cascade
#         ^
# SyntaxError: invalid syntax

# %%
pip install

# %%
pip install

# %%
pip install brainrender
# Out:
# ...
#      |████████████████████████████████| 102 kB 2.4 MB/s ta 0:00:011
# ...
#      |████████████████████████████████| 123 kB 12.5 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 80.6 MB 323 kB/s  eta 0:00:01     |████████████████▉               | 42.4 MB 15.4 MB/s eta 0:00:03
# ...
#      |████████████████████████████████| 57 kB 7.8 MB/s  eta 0:00:01
# ...
#      |████████████████████████████████| 12.0 MB 19.2 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 44 kB 4.2 MB/s  eta 0:00:01
# ...
#      |████████████████████████████████| 9.3 MB 8.6 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 95 kB 6.5 MB/s  eta 0:00:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# ...
#      |████████████████████████████████| 275 kB 14.0 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 45 kB 3.1 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 2.9 MB 21.9 MB/s eta 0:00:01
# ...

# %%
pip install cellfinder
# Out:
# ...
#      |████████████████████████████████| 199.0 MB 47 kB/s s eta 0:00:01     |████████████████████████████▎   | 176.1 MB 17.2 MB/s eta 0:00:02
# ...
#      |████████████████████████████████| 140 kB 19.9 MB/s eta 0:00:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#     Preparing wheel metadata ... done
# ...
#      |████████████████████████████████| 42 kB 2.4 MB/s  eta 0:00:01
# ...
#      |████████████████████████████████| 1.0 MB 13.7 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 2.9 MB 15.2 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 57 kB 6.8 MB/s  eta 0:00:01
# ...
#      |████████████████████████████████| 1.3 MB 20.1 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 5.6 MB 17.8 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 462 kB 16.2 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 65 kB 7.4 MB/s  eta 0:00:01
# ...

# %%
pip install bg-atlasapi
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install cellpose
# Out:
# ...
#      |████████████████████████████████| 13.3 MB 742 kB/s eta 0:00:01    |█████████████                   | 5.4 MB 1.0 MB/s eta 0:00:08
# ...
#      |████████████████████████████████| 218.8 MB 38 kB/s s eta 0:00:01
# ...
#      |████████████████████████████████| 89.2 MB 16.4 MB/s eta 0:00:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# ...
#   Created wheel for cellpose: filename=cellpose-0.6.5-py3-none-any.whl size=152504 sha256=c27b4fb04940b68e81bb40ceae96a18abf13b3a30bc6dbf3398dd5bf6fc39631
#   Stored in directory: /Users/aidanlew/Library/Caches/pip/wheels/6e/67/a1/55c05554f018f628e493530749ddb206501be4b99fc5815fd3
# ...
# anceled
# ERROR: Operation cancelled by user
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install MorphometricAnalysis
# Out:
# ERROR: Could not find a version that satisfies the requirement MorphometricAnalysis (from versions: none)
# ERROR: No matching distribution found for MorphometricAnalysis
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install BarDensr
# Out:
# ERROR: Could not find a version that satisfies the requirement BarDensr (from versions: none)
# ERROR: No matching distribution found for BarDensr
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install brainreg
# Out:
# ...
#      |████████████████████████████████| 40.8 MB 15.3 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 55 kB 6.8 MB/s  eta 0:00:01
# ...
#      |████████████████████████████████| 13.0 MB 15.1 MB/s eta 0:00:01
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# ...
#      |████████████████████████████████| 1.6 MB 18.4 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 3.3 MB 17.3 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 171 kB 20.1 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 236 kB 18.5 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 253 kB 17.6 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 163 kB 20.6 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 97 kB 6.0 MB/s  eta 0:00:01
# ...
#      |████████████████████████████████| 211 kB 19.5 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 4.3 MB 25.6 MB/s eta 0:00:01
# ...
